# %% [markdown]
# # Processing JSON Data
#
# - [Link](https://ch-nabarun.medium.com/read-json-using-pyspark-f792bda95741)

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext
from pyspark.sql import functions as F
from urllib.request import Request, urlopen

# %%
spark = (SparkSession
        .builder
        .appName("json-processing")
        .getOrCreate()
        )

sc = spark._sc

# %% [markdown]
# ## #1 Simple JSON (Each line contains a JSON Document)

# %% [markdown]
# ## #2 Multi line JSON

# %%
df = (
    spark
    .read
    .option("multiLine","true")
    .json('/Users/rk/Desktop/data/multi-line-json.json')
)

# %%
df.printSchema()
# Out:
# root
#  |-- nationality: string (nullable = true)
#  |-- results: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- cell: string (nullable = true)
#  |    |    |    |-- dob: long (nullable = true)
#  |    |    |    |-- email: string (nullable = true)
#  |    |    |    |-- gender: string (nullable = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- street: string (nullable = true)
#  |    |    |    |    |-- zip: long (nullable = true)
#  |    |    |    |-- md5: string (nullable = true)
#  |    |    |    |-- name: struct (nullable = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- password: string (nullable = true)
#  |    |    |    |-- phone: string (nullable = true)
#  |    |    |    |-- picture: struct (nullable = true)
#  |    |    |    |    |-- large: string (nullable = true)
#  |    |    |    |    |-- medium: string (nullable = true)
#  |    |    |    |    |-- thumbnail: string (nullable = true)
#  |    |    |    |-- registered: long (nullable = true)
#  |    |    |    |-- salt: string (nullable = true)
#  |    |    |    |-- sha1: string (nullable = true)
#  |    |    |    |-- sha256: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |-- seed: string (nullable = true)
#  |-- version: string (nullable = true)

# %%
df.columns
# Out:
# ['nationality', 'results', 'seed', 'version']

# %%
df = df.withColumn('results',F.explode('results'))

# Read location and name
df.select("results.user.location.*","results.user.name.*").show()
# Out:
# +----------+-----------------+--------------------+-----+--------+---------+-----+
# |      city|            state|              street|  zip|   first|     last|title|
# +----------+-----------------+--------------------+-----+--------+---------+-----+
# |tuttlingen|   sachsen-anhalt|   1307 kastanienweg|39587|  daniel|    heinz|   mr|
# | straubing|      brandenburg|   4916 wiesenstraße|42722|  amanda|    bruns| miss|
# |     essen|baden-württemberg|      8948 gartenweg|31250| bastian|schreiner|   mr|
# |      leer|    niedersachsen|     7017 kirchplatz|80447|frederik|     adam|   mr|
# |      daun|baden-württemberg|       7359 kirchweg|80580| laurenz| dittrich|   mr|
# |  dortmund|        thüringen|     5162 drosselweg|23302|   tommi| gebhardt|   mr|
# | helmstedt|           bayern|5703 berliner straße|17288|   fritz|     lang|   mr|
# |     börde|      brandenburg|     6664 poststraße|66107|angelina|     fink| miss|
# | offenbach|baden-württemberg|   4697 uhlandstraße|29392|  robert|     pohl|   mr|
# |burgenland|    niedersachsen|      2386 mittelweg|72298|benedikt|  richter|   mr|
# +----------+-----------------+--------------------+-----+--------+---------+-----+

# %% [markdown]
# ## #3 Read JSON Data from http

# %%
# Online data source
url = 'https://randomuser.me/api/0.8/?results=10'

# read the online data file
data = urlopen(url).read().decode('utf-8')

# %%
print(data)
# Out:
# {
#     "results": [
#         {
#             "user": {
#                 "gender": "male",
#                 "name": {
#                     "title": "mr",
#                     "first": "liam",
#                     "last": "johnson"
#                 },
#                 "location": {
#                     "street": "8524 grand ave",
#                     "city": "kingston",
#                     "state": "alberta",
#                     "zip": 84469
#                 },
#                 "email": "liam.johnson@example.com",
#                 "username": "whitekoala531",
#                 "password": "ursitesux",
#                 "salt": "0qkdl10I",
#                 "md5": "2a9e865c19740317496edf5475d9b451",
#                 "sha1": "4a344da5552157239882eacc9c79da87ab615b64",
#                 "sha256": "bf5dca2f43a33cccb2d41f5d5db7585e573f3e9debdff04e34617af45d02d08f",
#                 "registered": 1419353813,
#                 "dob": 233012308,
#                 "phone": "438-239-0752",
#                 "cell": "038-465-4170",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/men/51.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/men/51.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/men/51.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "male",
#                 "name": {
#                     "title": "mr",
#                     "first": "charles",
#                     "last": "lavigne"
#                 },
#                 "location": {
#                     "street": "6512 dufferin st",
#                     "city": "princeton",
#                     "state": "ontario",
#                     "zip": 94538
#                 },
#                 "email": "charles.lavigne@example.com",
#                 "username": "purpledog669",
#                 "password": "olemiss",
#                 "salt": "w8wNictT",
#                 "md5": "f5b8c3699eff312807090296d64e7674",
#                 "sha1": "66b6bdebf33191ed0e56486d4aa6fadda4ddecc1",
#                 "sha256": "597d7cb1dde9bbcbc258540d7da1a28e095f7bfa0fde1b466ae3626a3e532b27",
#                 "registered": 1435657042,
#                 "dob": 395571170,
#                 "phone": "954-122-6907",
#                 "cell": "903-834-1659",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/men/13.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/men/13.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/men/13.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "female",
#                 "name": {
#                     "title": "ms",
#                     "first": "addison",
#                     "last": "lavoie"
#                 },
#                 "location": {
#                     "street": "7386 college ave",
#                     "city": "charlottetown",
#                     "state": "ontario",
#                     "zip": 30862
#                 },
#                 "email": "addison.lavoie@example.com",
#                 "username": "brownladybug283",
#                 "password": "everett",
#                 "salt": "pKYUDwlD",
#                 "md5": "f5d2d47491cb4930c51ecd6b15b044ef",
#                 "sha1": "81d5d191b39cd22cac2a21bb9e4e981b1e1d0c4c",
#                 "sha256": "e32b5a385488dc1e8830a049510a5c76b9634d47719161c7fc4f146adc3e1e67",
#                 "registered": 1080368793,
#                 "dob": 1103302093,
#                 "phone": "937-302-6434",
#                 "cell": "084-892-3668",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/women/10.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/women/10.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/women/10.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "male",
#                 "name": {
#                     "title": "mr",
#                     "first": "leo",
#                     "last": "sirko"
#                 },
#                 "location": {
#                     "street": "3816 elgin st",
#                     "city": "windsor",
#                     "state": "alberta",
#                     "zip": 58543
#                 },
#                 "email": "leo.sirko@example.com",
#                 "username": "lazypanda101",
#                 "password": "deep",
#                 "salt": "pMztZJ0g",
#                 "md5": "5a20418639ede5a076b5f935628bc2db",
#                 "sha1": "4d5abc2915636b58089646941172224102ddbdb3",
#                 "sha256": "91dd773682459d550618c1a7a6e10e56527ebab3526ef1f96a98bb978316c469",
#                 "registered": 977419196,
#                 "dob": 520364950,
#                 "phone": "122-292-6207",
#                 "cell": "277-725-4243",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/men/70.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/men/70.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/men/70.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "female",
#                 "name": {
#                     "title": "ms",
#                     "first": "ariane",
#                     "last": "anderson"
#                 },
#                 "location": {
#                     "street": "8247 parliament st",
#                     "city": "trout lake",
#                     "state": "nova scotia",
#                     "zip": 63080
#                 },
#                 "email": "ariane.anderson@example.com",
#                 "username": "redmeercat366",
#                 "password": "putter",
#                 "salt": "d1PKAnrP",
#                 "md5": "b3719ba724afe91129f5d5e5b8f84655",
#                 "sha1": "71813c7e1a752fb1b7655de604026a2d15f92f11",
#                 "sha256": "370a8218eb5681766cc11c7d58f6b803c51f8c5418a4a8be6a039e51977dd557",
#                 "registered": 1017912479,
#                 "dob": 317019928,
#                 "phone": "171-557-8902",
#                 "cell": "305-857-4016",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/women/72.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/women/72.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/women/72.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "male",
#                 "name": {
#                     "title": "mr",
#                     "first": "benjamin",
#                     "last": "wong"
#                 },
#                 "location": {
#                     "street": "1243 concession road 6",
#                     "city": "sandy lake",
#                     "state": "new brunswick",
#                     "zip": 17446
#                 },
#                 "email": "benjamin.wong@example.com",
#                 "username": "greenostrich864",
#                 "password": "bdsm",
#                 "salt": "JTSHfeJh",
#                 "md5": "c04131da188319fc2b1002fdb11633cc",
#                 "sha1": "558dce6b1ccf6d026043dfcae8012a00caf25b99",
#                 "sha256": "4746d4ae2505350b1bc440f09ab06941913bbd25d54d0546d931bef638403b37",
#                 "registered": 1310154123,
#                 "dob": 538100414,
#                 "phone": "353-620-8240",
#                 "cell": "204-828-1143",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/men/99.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/men/99.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/men/99.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "male",
#                 "name": {
#                     "title": "mr",
#                     "first": "noah",
#                     "last": "gill"
#                 },
#                 "location": {
#                     "street": "6769 oak st",
#                     "city": "inwood",
#                     "state": "british columbia",
#                     "zip": 59273
#                 },
#                 "email": "noah.gill@example.com",
#                 "username": "organicmeercat501",
#                 "password": "danzig",
#                 "salt": "Wmvc55ln",
#                 "md5": "8824b55f32f5f09a0225b145e60fadf4",
#                 "sha1": "0a43fb846ab63708c84723e0268feedb01f12db0",
#                 "sha256": "3c0d40782524a95ca12b1090912876d772dea421f0749405856dd24e8473f58e",
#                 "registered": 1097859048,
#                 "dob": 944943006,
#                 "phone": "226-319-8922",
#                 "cell": "489-376-2488",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/men/35.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/men/35.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/men/35.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "female",
#                 "name": {
#                     "title": "ms",
#                     "first": "brielle",
#                     "last": "lo"
#                 },
#                 "location": {
#                     "street": "3802 king st",
#                     "city": "havelock",
#                     "state": "northwest territories",
#                     "zip": 19965
#                 },
#                 "email": "brielle.lo@example.com",
#                 "username": "yellowkoala285",
#                 "password": "hobbes",
#                 "salt": "n1Y92rDT",
#                 "md5": "2d3511f99b0d6bccd6fd336e29984297",
#                 "sha1": "0578af9bcf9c455f97052658ec985aa7b3b2010d",
#                 "sha256": "c4e153378cff538ed9e04d46502ee91805bc976ad77405129dc36f4d115dcdef",
#                 "registered": 1330697212,
#                 "dob": 1307415460,
#                 "phone": "516-253-7356",
#                 "cell": "263-768-2543",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/women/46.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/women/46.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/women/46.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "female",
#                 "name": {
#                     "title": "miss",
#                     "first": "alice",
#                     "last": "french"
#                 },
#                 "location": {
#                     "street": "4837 dufferin st",
#                     "city": "kingston",
#                     "state": "northwest territories",
#                     "zip": 99262
#                 },
#                 "email": "alice.french@example.com",
#                 "username": "ticklishwolf879",
#                 "password": "tiger2",
#                 "salt": "2pwHjKEI",
#                 "md5": "257bffc048ec4910f3647fcb0d2800ec",
#                 "sha1": "fae1ad2dabbfd97522ddad19fe7b4fc89b32389a",
#                 "sha256": "ccc17f9bd35caebf5c509fe965024352cacede10157dfae270fc6aed1a7b5d09",
#                 "registered": 1020103841,
#                 "dob": 616903456,
#                 "phone": "713-158-9787",
#                 "cell": "194-157-1602",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/women/34.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/women/34.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/women/34.jpg"
#                 }
#             }
#         },
#         {
#             "user": {
#                 "gender": "male",
#                 "name": {
#                     "title": "mr",
#                     "first": "carter",
#                     "last": "chow"
#                 },
#                 "location": {
#                     "street": "9109 arctic way",
#                     "city": "princeton",
#                     "state": "alberta",
#                     "zip": 77910
#                 },
#                 "email": "carter.chow@example.com",
#                 "username": "blackpanda365",
#                 "password": "zelda",
#                 "salt": "sJBLHwtg",
#                 "md5": "c04a36791c439d84721fd90a905a454d",
#                 "sha1": "f1696c02fe5ab0a5668ad7d298e839056bb8af1c",
#                 "sha256": "fb9804b12824212f7cc5db611e502ce7a4374469503b72fefcf806de57fc1597",
#                 "registered": 1227151681,
#                 "dob": 664707734,
#                 "phone": "631-466-5373",
#                 "cell": "342-323-2238",
#                 "picture": {
#                     "large": "https://randomuser.me/api/portraits/men/1.jpg",
#                     "medium": "https://randomuser.me/api/portraits/med/men/1.jpg",
#                     "thumbnail": "https://randomuser.me/api/portraits/thumb/men/1.jpg"
#                 }
#             }
#         }
#     ],
#     "nationality": "CA",
#     "seed": "bf63979a09212ed602",
#     "version": "0.8"
# }

# %%
rdd = sc.parallelize([data])

# create a Dataframe
jsonDF = spark.read.json(rdd)

# %%
jsonDF.show()
# Out:
# +-----------+--------------------+------------------+-------+
# |nationality|             results|              seed|version|
# +-----------+--------------------+------------------+-------+
# |         CA|[[[038-465-4170, ...|bf63979a09212ed602|    0.8|
# +-----------+--------------------+------------------+-------+

# %%
# read all the users name:
results = (
    jsonDF
    .withColumn('results', F.explode('results'))
    .select('results.user.name.*', 
            'results.user.location.*', 
            'results.user.email',
            'results.user.username',
            'results.user.password',
            'results.user.salt',
            'results.user.md5',
            'results.user.sha1',
            'results.user.sha256',
            'results.user.dob',
            'results.user.phone',
            'results.user.cell',
            'results.user.picture.*'
           )
)

results.toPandas()
# Out:
#       first      last title           city                  state  \
# 0      liam   johnson    mr       kingston                alberta
# 1   charles   lavigne    mr      princeton                ontario
# 2   addison    lavoie    ms  charlottetown                ontario
# 3       leo     sirko    mr        windsor                alberta
# 4    ariane  anderson    ms     trout lake            nova scotia
# 5  benjamin      wong    mr     sandy lake          new brunswick
# 6      noah      gill    mr         inwood       british columbia
# 7   brielle        lo    ms       havelock  northwest territories
# 8     alice    french  miss       kingston  northwest territories
# 9    carter      chow    mr      princeton                alberta
#
#                    street    zip                        email  \
# 0          8524 grand ave  84469     liam.johnson@example.com
# 1        6512 dufferin st  94538  charles.lavigne@example.com
# 2        7386 college ave  30862   addison.lavoie@example.com
# 3           3816 elgin st  58543        leo.sirko@example.com
# 4      8247 parliament st  63080  ariane.anderson@example.com
# 5  1243 concession road 6  17446    benjamin.wong@example.com
# 6             6769 oak st  59273        noah.gill@example.com
# 7            3802 king st  19965       brielle.lo@example.com
# 8        4837 dufferin st  99262     alice.french@example.com
# 9         9109 arctic way  77910      carter.chow@example.com
#
#             username   password      salt                               md5  \
# 0      whitekoala531  ursitesux  0qkdl10I  2a9e865c19740317496edf5475d9b451
# 1       purpledog669    olemiss  w8wNictT  f5b8c3699eff312807090296d64e7674
# 2    brownladybug283    everett  pKYUDwlD  f5d2d47491cb4930c51ecd6b15b044ef
# 3       lazypanda101       deep  pMztZJ0g  5a20418639ede5a076b5f935628bc2db
# 4      redmeercat366     putter  d1PKAnrP  b3719ba724afe91129f5d5e5b8f84655
# 5    greenostrich864       bdsm  JTSHfeJh  c04131da188319fc2b1002fdb11633cc
# 6  organicmeercat501     danzig  Wmvc55ln  8824b55f32f5f09a0225b145e60fadf4
# 7     yellowkoala285     hobbes  n1Y92rDT  2d3511f99b0d6bccd6fd336e29984297
# 8    ticklishwolf879     tiger2  2pwHjKEI  257bffc048ec4910f3647fcb0d2800ec
# 9      blackpanda365      zelda  sJBLHwtg  c04a36791c439d84721fd90a905a454d
#
#                                        sha1  \
# 0  4a344da5552157239882eacc9c79da87ab615b64
# 1  66b6bdebf33191ed0e56486d4aa6fadda4ddecc1
# 2  81d5d191b39cd22cac2a21bb9e4e981b1e1d0c4c
# 3  4d5abc2915636b58089646941172224102ddbdb3
# 4  71813c7e1a752fb1b7655de604026a2d15f92f11
# 5  558dce6b1ccf6d026043dfcae8012a00caf25b99
# 6  0a43fb846ab63708c84723e0268feedb01f12db0
# 7  0578af9bcf9c455f97052658ec985aa7b3b2010d
# 8  fae1ad2dabbfd97522ddad19fe7b4fc89b32389a
# 9  f1696c02fe5ab0a5668ad7d298e839056bb8af1c
#
#                                               sha256         dob  \
# 0  bf5dca2f43a33cccb2d41f5d5db7585e573f3e9debdff0...   233012308
# 1  597d7cb1dde9bbcbc258540d7da1a28e095f7bfa0fde1b...   395571170
# 2  e32b5a385488dc1e8830a049510a5c76b9634d47719161...  1103302093
# 3  91dd773682459d550618c1a7a6e10e56527ebab3526ef1...   520364950
# 4  370a8218eb5681766cc11c7d58f6b803c51f8c5418a4a8...   317019928
# 5  4746d4ae2505350b1bc440f09ab06941913bbd25d54d05...   538100414
# 6  3c0d40782524a95ca12b1090912876d772dea421f07494...   944943006
# 7  c4e153378cff538ed9e04d46502ee91805bc976ad77405...  1307415460
# 8  ccc17f9bd35caebf5c509fe965024352cacede10157dfa...   616903456
# 9  fb9804b12824212f7cc5db611e502ce7a4374469503b72...   664707734
#
#           phone          cell  \
# 0  438-239-0752  038-465-4170
# 1  954-122-6907  903-834-1659
# 2  937-302-6434  084-892-3668
# 3  122-292-6207  277-725-4243
# 4  171-557-8902  305-857-4016
# 5  353-620-8240  204-828-1143
# 6  226-319-8922  489-376-2488
# 7  516-253-7356  263-768-2543
# 8  713-158-9787  194-157-1602
# 9  631-466-5373  342-323-2238
#
#                                               large  \
# 0    https://randomuser.me/api/portraits/men/51.jpg
# 1    https://randomuser.me/api/portraits/men/13.jpg
# 2  https://randomuser.me/api/portraits/women/10.jpg
# 3    https://randomuser.me/api/portraits/men/70.jpg
# 4  https://randomuser.me/api/portraits/women/72.jpg
# 5    https://randomuser.me/api/portraits/men/99.jpg
# 6    https://randomuser.me/api/portraits/men/35.jpg
# 7  https://randomuser.me/api/portraits/women/46.jpg
# 8  https://randomuser.me/api/portraits/women/34.jpg
# 9     https://randomuser.me/api/portraits/men/1.jpg
#
#                                               medium  \
# 0  https://randomuser.me/api/portraits/med/men/51...
# 1  https://randomuser.me/api/portraits/med/men/13...
# 2  https://randomuser.me/api/portraits/med/women/...
# 3  https://randomuser.me/api/portraits/med/men/70...
# 4  https://randomuser.me/api/portraits/med/women/...
# 5  https://randomuser.me/api/portraits/med/men/99...
# 6  https://randomuser.me/api/portraits/med/men/35...
# 7  https://randomuser.me/api/portraits/med/women/...
# 8  https://randomuser.me/api/portraits/med/women/...
# 9  https://randomuser.me/api/portraits/med/men/1.jpg
#
#                                            thumbnail
# 0  https://randomuser.me/api/portraits/thumb/men/...
# 1  https://randomuser.me/api/portraits/thumb/men/...
# 2  https://randomuser.me/api/portraits/thumb/wome...
# 3  https://randomuser.me/api/portraits/thumb/men/...
# 4  https://randomuser.me/api/portraits/thumb/wome...
# 5  https://randomuser.me/api/portraits/thumb/men/...
# 6  https://randomuser.me/api/portraits/thumb/men/...
# 7  https://randomuser.me/api/portraits/thumb/wome...
# 8  https://randomuser.me/api/portraits/thumb/wome...
# 9  https://randomuser.me/api/portraits/thumb/men/...

# %% [markdown]
# ## CSV File containing JSON Data
#
# Note: **I could not find a CSV file with a JSON column. Below code is not tested.**

# %%
df = (spark
      .read
      .option('multiLine',"true")
      .option('escape','\"')
      .option('header', False)
      .csv('/Users/rk/Desktop/data/csv-with-json-data.csv')
     )

# %%
df.show()
# Out:
# +--------------------+----+----+
# |                 _c0| _c1| _c2|
# +--------------------+----+----+
# |                 Tom|   B|  { |
# |         "student":{|null|null|
# |          "name":...|null|null|
# |                   }|null|null|
# |                  } |null|null|
# +--------------------+----+----+

# %%
# escape all " in the JSON content to read properly
readCSVFileDF = spark.read.option("multiLine","true").option('escape',"\"").option('header',True).csv('mixJSON4.csv')
readCSVFileDF.printSchema()
readCSVFileDF.show(truncate=False)

# use JSON_TUPLE to read required contents : student, nationality and subject from Info column
readJSONContentDF1 = readCSVFileDF.select("*",F.json_tuple("Info","student","nationality","subject")).drop('Info')
readJSONContentDF1.show(truncate=False)

# use JSON_TUPLE to read student details - gender, city, email
readJSONContentDF2 = readJSONContentDF1.select('*',F.col('c1').alias('Nationality'),F.json_tuple('c0','gender','city','email').alias('Gender','City','MailId')).drop('c0','c1')
readJSONContentDF2.show(truncate=False)

# use JSON_TUPLE to read subject details - mainsubject and optional
finalDF = readJSONContentDF2.select('*',F.json_tuple('c2','main','optional').alias('MainSubject','OptionalSubject')).drop('c2')
finalDF.show(truncate=False)


# another way : using withcolumn
readJSONDF = readCSVFileDF.select("*",F.json_tuple("Info","student","nationality","subject")).drop('Info')
readJSONDF.show(truncate=False)

finalDF1 = readJSONDF.withColumn('Gender',F.json_tuple('c0','gender')).\
    withColumn('City',F.json_tuple('c0','city')).\
    withColumn('MailId',F.json_tuple('c0','email')).\
    withColumn('MainSubject',F.json_tuple('c2','main')).\
    withColumn('OptionalSubject',F.json_tuple('c2','optional')).\
    withColumn('Nationality',F.col('c1')).drop('c0','c1','c2')

finalDF1.show(truncate=False)
